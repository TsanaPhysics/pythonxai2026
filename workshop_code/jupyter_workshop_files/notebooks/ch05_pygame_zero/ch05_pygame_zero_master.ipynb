# %% [markdown]
# # 🎮 บทที่ 5: Digital Twin Simulation
# **Course**: Python x AI 2026
# **Instructor**: ผศ.ดร.ชีวะ ทัศนา

# %% [markdown]
# ## 🕒 Lab Activity 1

# %%
import pgzrun

WIDTH = 800
HEIGHT = 600

harvester = Actor('harvester')
harvester.pos = 400, 300

def draw():
    screen.clear()
    screen.fill((34, 139, 34)) # สีเขียวฟาร์ม
    harvester.draw()
    screen.draw.text("Agri-AI Simulation Mode", (20, 20), color="white", fontsize=30)

def update():
    if keyboard.space:
        harvester.x += 2
        
pgzrun.go()
